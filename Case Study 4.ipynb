# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
regions=pd.read_csv(r"C:\Users\yuvin\Downloads\regions.csv")
regions
# Out:
#    Unnamed: 0  region_id region_name
# 0           0          1   Australia
# 1           1          2     America
# 2           2          3      Africa
# 3           3          4        Asia
# 4           4          5      Europe

# %%
C_N=pd.read_csv(r"C:\Users\yuvin\Downloads\customer_nodes.csv")
C_N
# Out:
#       Unnamed: 0  customer_id  region_id  node_id  start_date    end_date
# 0              0            1          3        4  2020-01-02  2020-01-03
# 1              1            2          3        5  2020-01-03  2020-01-17
# 2              2            3          5        4  2020-01-27  2020-02-18
# 3              3            4          5        4  2020-01-07  2020-01-19
# 4              4            5          3        3  2020-01-15  2020-01-23
# ...          ...          ...        ...      ...         ...         ...
# 3495        3495          496          3        4  2020-02-25  9999-12-31
# 3496        3496          497          5        4  2020-05-27  9999-12-31
# 3497        3497          498          1        2  2020-04-05  9999-12-31
# 3498        3498          499          5        1  2020-02-03  9999-12-31
# 3499        3499          500          2        2  2020-04-15  9999-12-31
#
# [3500 rows x 6 columns]

# %%
C_T=pd.read_csv(r"C:\Users\yuvin\Downloads\customer_transactions.csv")
C_T
# Out:
#       Unnamed: 0  customer_id    txn_date    txn_type  txn_amount
# 0              0          429  2020-01-21     deposit          82
# 1              1          155  2020-01-10     deposit         712
# 2              2          398  2020-01-01     deposit         196
# 3              3          255  2020-01-14     deposit         563
# 4              4          185  2020-01-29     deposit         626
# ...          ...          ...         ...         ...         ...
# 5863        5863          189  2020-02-03  withdrawal         870
# 5864        5864          189  2020-03-22    purchase         718
# 5865        5865          189  2020-02-06    purchase         393
# 5866        5866          189  2020-01-22     deposit         302
# 5867        5867          189  2020-01-27  withdrawal         861
#
# [5868 rows x 5 columns]

# %% [markdown]
# # Customer Nodes Exploration

# %% [markdown]
# # 1.How many unique nodes are there on the Data Bank system?

# %%
C_N
# Out:
#       Unnamed: 0  customer_id  region_id  node_id  start_date    end_date
# 0              0            1          3        4  2020-01-02  2020-01-03
# 1              1            2          3        5  2020-01-03  2020-01-17
# 2              2            3          5        4  2020-01-27  2020-02-18
# 3              3            4          5        4  2020-01-07  2020-01-19
# 4              4            5          3        3  2020-01-15  2020-01-23
# ...          ...          ...        ...      ...         ...         ...
# 3495        3495          496          3        4  2020-02-25  9999-12-31
# 3496        3496          497          5        4  2020-05-27  9999-12-31
# 3497        3497          498          1        2  2020-04-05  9999-12-31
# 3498        3498          499          5        1  2020-02-03  9999-12-31
# 3499        3499          500          2        2  2020-04-15  9999-12-31
#
# [3500 rows x 6 columns]

# %%
C_N['node_id'].nunique()
# Out:
# 5

# %%
sns.histplot(data=C_N,x='node_id',color='red')
# Out:
# <Axes: xlabel='node_id', ylabel='Count'>

# %% [markdown]
# # 2.What is the number of nodes per region?

# %%
C_N
# Out:
#       Unnamed: 0  customer_id  region_id  node_id  start_date    end_date
# 0              0            1          3        4  2020-01-02  2020-01-03
# 1              1            2          3        5  2020-01-03  2020-01-17
# 2              2            3          5        4  2020-01-27  2020-02-18
# 3              3            4          5        4  2020-01-07  2020-01-19
# 4              4            5          3        3  2020-01-15  2020-01-23
# ...          ...          ...        ...      ...         ...         ...
# 3495        3495          496          3        4  2020-02-25  9999-12-31
# 3496        3496          497          5        4  2020-05-27  9999-12-31
# 3497        3497          498          1        2  2020-04-05  9999-12-31
# 3498        3498          499          5        1  2020-02-03  9999-12-31
# 3499        3499          500          2        2  2020-04-15  9999-12-31
#
# [3500 rows x 6 columns]

# %%
C_N.groupby('region_id')['node_id'].nunique().plot(kind='pie')
# Out:
# <Axes: ylabel='node_id'>

# %% [markdown]
# # 3.How many customers are allocated to each region?

# %%
C_N
# Out:
#       Unnamed: 0  customer_id  region_id  node_id  start_date    end_date
# 0              0            1          3        4  2020-01-02  2020-01-03
# 1              1            2          3        5  2020-01-03  2020-01-17
# 2              2            3          5        4  2020-01-27  2020-02-18
# 3              3            4          5        4  2020-01-07  2020-01-19
# 4              4            5          3        3  2020-01-15  2020-01-23
# ...          ...          ...        ...      ...         ...         ...
# 3495        3495          496          3        4  2020-02-25  9999-12-31
# 3496        3496          497          5        4  2020-05-27  9999-12-31
# 3497        3497          498          1        2  2020-04-05  9999-12-31
# 3498        3498          499          5        1  2020-02-03  9999-12-31
# 3499        3499          500          2        2  2020-04-15  9999-12-31
#
# [3500 rows x 6 columns]

# %%
C_T
# Out:
#       Unnamed: 0  customer_id    txn_date    txn_type  txn_amount
# 0              0          429  2020-01-21     deposit          82
# 1              1          155  2020-01-10     deposit         712
# 2              2          398  2020-01-01     deposit         196
# 3              3          255  2020-01-14     deposit         563
# 4              4          185  2020-01-29     deposit         626
# ...          ...          ...         ...         ...         ...
# 5863        5863          189  2020-02-03  withdrawal         870
# 5864        5864          189  2020-03-22    purchase         718
# 5865        5865          189  2020-02-06    purchase         393
# 5866        5866          189  2020-01-22     deposit         302
# 5867        5867          189  2020-01-27  withdrawal         861
#
# [5868 rows x 5 columns]

# %%
x=pd.merge(C_N,C_T,how='inner')
x
# Out:
#    Unnamed: 0  customer_id  region_id  node_id  start_date    end_date  \
# 0         328          329          5        5  2020-01-07  2020-01-16
# 1         637          138          4        3  2020-01-29  2020-02-08
# 2        1590           91          4        1  2020-02-28  2020-03-19
# 3        1881          382          4        5  2020-01-31  2020-02-08
# 4        1915          416          1        3  2020-03-08  2020-04-03
# 5        2563           64          2        4  2020-03-31  2020-04-26
# 6        2902          403          3        2  2020-04-24  2020-04-29
# 7        3446          447          5        1  2020-04-02  9999-12-31
#
#      txn_date    txn_type  txn_amount
# 0  2020-01-07     deposit         723
# 1  2020-03-29     deposit          15
# 2  2020-02-12     deposit         796
# 3  2020-02-22  withdrawal         579
# 4  2020-02-02     deposit         996
# 5  2020-01-25     deposit         993
# 6  2020-01-24  withdrawal          60
# ...

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   8 non-null      int64
#  1   customer_id  8 non-null      int64
#  2   region_id    8 non-null      int64
#  3   node_id      8 non-null      int64
#  4   start_date   8 non-null      object
#  5   end_date     8 non-null      object
#  6   txn_date     8 non-null      object
#  7   txn_type     8 non-null      object
#  8   txn_amount   8 non-null      int64
# dtypes: int64(5), object(4)
# memory usage: 708.0+ bytes

# %%
x.groupby('region_id')['customer_id'].sum()
# Out:
# region_id
# 1    416
# 2     64
# 3    403
# 4    611
# 5    776
# Name: customer_id, dtype: int64

# %%
x.groupby('region_id')['customer_id'].sum().plot(kind='barh',color='violet')
# Out:
# <Axes: ylabel='region_id'>

# %% [markdown]
# ### Insights
# ##### 1.The no of customers for each region is
# #### `The customers in the region 1 are   - 416`,
# ####   `The customers in the region 2 are  -   64`,
# #### `The customers in the region 3 are    403` ,
# #### `The customers in the region 4 are    611`,
# #### `The customers in the region 5 are    776`
# #### Tje region 5 has the maximun no of customers where as 2 region has the lowest no of customers

# %% [markdown]
# ### from the above histogram we conclude that region 5 has the highest customers and region 2 has the lowest in the databank systems

# %% [markdown]
# # Using matplotlib lib

# %%
import matplotlib.pyplot as plt

# %%
totals = x.groupby('region_id')['customer_id'].sum()

plt.bar(totals.index, totals.values, color='green')
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# # 4.How many days on average are customers reallocated to a different node?

# %%
x
# Out:
#    Unnamed: 0  customer_id  region_id  node_id  start_date    end_date  \
# 0         328          329          5        5  2020-01-07  2020-01-16
# 1         637          138          4        3  2020-01-29  2020-02-08
# 2        1590           91          4        1  2020-02-28  2020-03-19
# 3        1881          382          4        5  2020-01-31  2020-02-08
# 4        1915          416          1        3  2020-03-08  2020-04-03
# 5        2563           64          2        4  2020-03-31  2020-04-26
# 6        2902          403          3        2  2020-04-24  2020-04-29
# 7        3446          447          5        1  2020-04-02  9999-12-31
#
#      txn_date    txn_type  txn_amount
# 0  2020-01-07     deposit         723
# 1  2020-03-29     deposit          15
# 2  2020-02-12     deposit         796
# 3  2020-02-22  withdrawal         579
# 4  2020-02-02     deposit         996
# 5  2020-01-25     deposit         993
# 6  2020-01-24  withdrawal          60
# ...

# %%
Start_Date=pd.to_datetime(x['start_date'])

# %%
End_Date=pd.to_datetime(x['end_date'],errors = 'coerce')

# %%
Avg_days=(End_Date-Start_Date).mean().days

# %%
Avg_days
# Out:
# 14

# %% [markdown]
# # The no of days the customers are reallocated to a different node is `14`

# %% [markdown]
# # `Customer Transactions`
# ### 5 What is the unique count and total amount for each transaction type?

# %%
C_T = C_T.drop('Unnamed: 0', axis = 1)

# %%
C_T

# %%
C_T.groupby('txn_type')['customer_id'].nunique()

# %%
C_T.groupby('txn_type')['customer_id'].nunique().plot(kind='bar',color='darkmagenta')

# %%
C_T.groupby('txn_type')['customer_id'].nunique().plot(kind='line',color='darkmagenta')
# Out:
# <Axes: xlabel='txn_type'>

# %% [markdown]
# ### Insights

# %% [markdown]
# #### 1.The more no of transaction type is through purchase(`500`)
# #### 2.The less no of transaction type is through withdrawl(`439`)

# %%
C_T.groupby('txn_type')['txn_amount'].sum()
# Out:
# txn_type
# deposit       1359168
# purchase       806537
# withdrawal     793003
# Name: txn_amount, dtype: int64

# %%
C_T.groupby('txn_type')['txn_amount'].sum().plot(kind='bar',color='springgreen')
# Out:
# <Axes: xlabel='txn_type'>

# %% [markdown]
# # 6.What is the average total historical deposit counts and amounts for all customers?

# %%
C_T
# Out:
#       Unnamed: 0  customer_id    txn_date    txn_type  txn_amount
# 0              0          429  2020-01-21     deposit          82
# 1              1          155  2020-01-10     deposit         712
# 2              2          398  2020-01-01     deposit         196
# 3              3          255  2020-01-14     deposit         563
# 4              4          185  2020-01-29     deposit         626
# ...          ...          ...         ...         ...         ...
# 5863        5863          189  2020-02-03  withdrawal         870
# 5864        5864          189  2020-03-22    purchase         718
# 5865        5865          189  2020-02-06    purchase         393
# 5866        5866          189  2020-01-22     deposit         302
# 5867        5867          189  2020-01-27  withdrawal         861
#
# [5868 rows x 5 columns]

# %%
avg_historical_deposit_count=C_T[C_T['txn_type']=='deposit'].groupby('customer_id')['txn_date'].count().mean()
avg_historical_deposit_count
# Out:
# 5.342

# %%
avg_historical_deposit_amount=C_T[C_T['txn_type']=='deposit'].groupby('customer_id')['txn_amount'].sum().mean()
avg_historical_deposit_amount
# Out:
# 2718.336

# %% [markdown]
# # 7.For each month - how many Data Bank customers make more than 1 deposit and either 1 purchase or 1 withdrawal in a single month?

# %%
C_T
# Out:
#       Unnamed: 0  customer_id    txn_date    txn_type  txn_amount
# 0              0          429  2020-01-21     deposit          82
# 1              1          155  2020-01-10     deposit         712
# 2              2          398  2020-01-01     deposit         196
# 3              3          255  2020-01-14     deposit         563
# 4              4          185  2020-01-29     deposit         626
# ...          ...          ...         ...         ...         ...
# 5863        5863          189  2020-02-03  withdrawal         870
# 5864        5864          189  2020-03-22    purchase         718
# 5865        5865          189  2020-02-06    purchase         393
# 5866        5866          189  2020-01-22     deposit         302
# 5867        5867          189  2020-01-27  withdrawal         861
#
# [5868 rows x 5 columns]

# %%
import pandas as pd

# Sample DataFrame with a date column
data = C_T['txn_date']
df=pd.DataFrame(data)

# Convert the 'date' column to datetime
df['date'] = pd.to_datetime(data)

# Extract the month from the 'date' column and create a new 'month' column
df['month'] = df['date'].dt.month

# %%
C_T['txn_date'] =(C_T['txn_date']).dt.month

# %%
deposits = C_T[C_T['txn_type'] == 'deposit']

# %%
customers_with_purchase_or_withdrawal = C_T[C_T['txn_type'].isin(['purchase', 'withdrawal'])]['customer_id'].unique()

# %%
monthly_activity = deposits[deposits['customer_id'].isin(customers_with_purchase_or_withdrawal)]

# %%
monthly_activity = monthly_activity.groupby(monthly_activity['txn_date']).agg({'customer_id': 'nunique'}).reset_index()

# %%
monthly_activity.columns = ['month', 'customers_count']

# %%
monthly_activity
# Out:
#    month  customers_count
# 0      1              485
# 1      2              341
# 2      3              366
# 3      4              199

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# Plotting using seaborn barplot
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
ax = sns.barplot(x='month', y='customers_count', data=monthly_activity, ci=None)

# Add legend
ax.legend(labels=['Number of Customers'], loc='upper left')

plt.title('Monthly Customer Activity')
plt.xlabel('Month')
plt.ylabel('Number of Customers')
plt.show()

# %% [markdown]
# # The 1st month has the highest no of  customers count
# # The 4th month has the lowest no of customers count

# %% [markdown]
# # 8.What is the median, 80th and 95th percentile for this same reallocation days metric for each region?

# %%
x
# Out:
#    Unnamed: 0  customer_id  region_id  node_id  start_date    end_date  \
# 0         328          329          5        5  2020-01-07  2020-01-16
# 1         637          138          4        3  2020-01-29  2020-02-08
# 2        1590           91          4        1  2020-02-28  2020-03-19
# 3        1881          382          4        5  2020-01-31  2020-02-08
# 4        1915          416          1        3  2020-03-08  2020-04-03
# 5        2563           64          2        4  2020-03-31  2020-04-26
# 6        2902          403          3        2  2020-04-24  2020-04-29
# 7        3446          447          5        1  2020-04-02  9999-12-31
#
#      txn_date    txn_type  txn_amount
# 0  2020-01-07     deposit         723
# 1  2020-03-29     deposit          15
# 2  2020-02-12     deposit         796
# 3  2020-02-22  withdrawal         579
# 4  2020-02-02     deposit         996
# 5  2020-01-25     deposit         993
# 6  2020-01-24  withdrawal          60
# ...

# %%
x['start_date'] = pd.to_datetime(x['start_date'],errors='coerce')
x['end_date'] = pd.to_datetime(x['end_date'],errors='coerce')

# Calculate the duration of each reallocation
x['duration'] = (x['end_date'] - x['start_date']).dt.days

# Add a new column named 'new_column'
x['new_column'] = 'Your New Values'  # Replace 'Your New Values' with the values you want to assign

# Display the DataFrame with the new column
print(x)
# Out:
#    Unnamed: 0  customer_id  region_id  node_id start_date   end_date  \
# 0         328          329          5        5 2020-01-07 2020-01-16
# 1         637          138          4        3 2020-01-29 2020-02-08
# 2        1590           91          4        1 2020-02-28 2020-03-19
# 3        1881          382          4        5 2020-01-31 2020-02-08
# 4        1915          416          1        3 2020-03-08 2020-04-03
# 5        2563           64          2        4 2020-03-31 2020-04-26
# 6        2902          403          3        2 2020-04-24 2020-04-29
# 7        3446          447          5        1 2020-04-02        NaT
#
#      txn_date    txn_type  txn_amount  duration       new_column
# 0  2020-01-07     deposit         723       9.0  Your New Values
# 1  2020-03-29     deposit          15      10.0  Your New Values
# 2  2020-02-12     deposit         796      20.0  Your New Values
# 3  2020-02-22  withdrawal         579       8.0  Your New Values
# ...

# %%
x.groupby('region_id')['duration'].agg(['median', lambda x : x.quantile(0.80), lambda x : x.quantile(0.95)])
# Out:
#            median  <lambda_0>  <lambda_1>
# region_id
# 1            26.0        26.0        26.0
# 2            26.0        26.0        26.0
# 3             5.0         5.0         5.0
# 4            10.0        16.0        19.0
# 5             9.0         9.0         9.0
