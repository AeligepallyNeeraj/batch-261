# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt,seaborn as sns,sklearn

# %%
gdf = pd.read_csv(r"C:\Users\yuvin\Downloads\german_credit_data_1.csv")
gdf
# Out:
#      Unnamed: 0  Age     Sex  Job Housing Saving accounts Checking account  \
# 0             0   67    male    2     own             NaN           little
# 1             1   22  female    2     own          little         moderate
# 2             2   49    male    1     own          little              NaN
# 3             3   45    male    2    free          little           little
# 4             4   53    male    2    free          little           little
# ..          ...  ...     ...  ...     ...             ...              ...
# 995         995   31  female    1     own          little              NaN
# 996         996   40    male    3     own          little           little
# 997         997   38    male    2     own          little              NaN
# 998         998   23    male    2    free          little           little
# 999         999   27    male    2     own        moderate         moderate
#
#      Credit amount  Duration              Purpose
# ...

# %% [markdown]
# * Age (numeric)
# * Sex (text: male, female)
# * Job (numeric: 0 - unskilled and non-resident, 1 - unskilled and resident, 2 - skilled, 3 - highly skilled)
# * Housing (text: own, rent, or free)
# * Saving accounts (text - little, moderate, quite rich, rich)
# * Checking account (numeric, in DM - Deutsch Mark)
# * Credit amount (numeric, in DM)
# * Duration (numeric, in month)
# * Purpose (text: car, furniture/equipment, radio/TV, domestic appliances, repairs, education, business, vacation/others)

# %%
gdf.drop(columns=['Unnamed: 0'],inplace=True)
gdf
# Out:
#      Age     Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 0     67    male    2     own             NaN           little           1169
# 1     22  female    2     own          little         moderate           5951
# 2     49    male    1     own          little              NaN           2096
# 3     45    male    2    free          little           little           7882
# 4     53    male    2    free          little           little           4870
# ..   ...     ...  ...     ...             ...              ...            ...
# 995   31  female    1     own          little              NaN           1736
# 996   40    male    3     own          little           little           3857
# 997   38    male    2     own          little              NaN            804
# 998   23    male    2    free          little           little           1845
# 999   27    male    2     own        moderate         moderate           4576
#
# ...

# %%
gdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               1000 non-null   int64
#  1   Sex               1000 non-null   object
#  2   Job               1000 non-null   int64
#  3   Housing           1000 non-null   object
#  4   Saving accounts   817 non-null    object
#  5   Checking account  606 non-null    object
#  6   Credit amount     1000 non-null   int64
#  7   Duration          1000 non-null   int64
#  8   Purpose           1000 non-null   object
# dtypes: int64(4), object(5)
# memory usage: 70.4+ KB

# %%
gdf['Job'].dtype
# Out:
# dtype('int64')

# %%
gdf['Job']=gdf['Job'].astype('object')#conversion of dtype from int64 to object
gdf['Job']
# Out:
# 0      2
# 1      2
# 2      1
# 3      2
# 4      2
#       ..
# 995    1
# 996    3
# 997    2
# 998    2
# 999    2
# Name: Job, Length: 1000, dtype: object

# %%
gdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               1000 non-null   int64
#  1   Sex               1000 non-null   object
#  2   Job               1000 non-null   object
#  3   Housing           1000 non-null   object
#  4   Saving accounts   817 non-null    object
#  5   Checking account  606 non-null    object
#  6   Credit amount     1000 non-null   int64
#  7   Duration          1000 non-null   int64
#  8   Purpose           1000 non-null   object
# dtypes: int64(3), object(6)
# memory usage: 70.4+ KB

# %%
gdf['Age'].min()
# Out:
# 19

# %%
gdf['Age'].max()#S o we can get the age ranges from 19 to 75 in this data
# Out:
# 75

# %%
gdf['Age'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
gdf['Age'].plot(kind='pie')
# Out:
# <Axes: ylabel='Age'>

# %% [markdown]
# # Gender

# %%
gdf[gdf['Sex']=='male']
# Out:
#      Age   Sex Job Housing Saving accounts Checking account  Credit amount  \
# 0     67  male   2     own             NaN           little           1169
# 2     49  male   1     own          little              NaN           2096
# 3     45  male   2    free          little           little           7882
# 4     53  male   2    free          little           little           4870
# 5     35  male   1    free             NaN              NaN           9055
# ..   ...   ...  ..     ...             ...              ...            ...
# 994   50  male   2     own             NaN              NaN           2390
# 996   40  male   3     own          little           little           3857
# 997   38  male   2     own          little              NaN            804
# 998   23  male   2    free          little           little           1845
# 999   27  male   2     own        moderate         moderate           4576
#
#      Duration              Purpose
# ...

# %%
gdf[gdf['Sex']=='male'].value_counts()
# Out:
# Age  Sex   Job  Housing  Saving accounts  Checking account  Credit amount  Duration  Purpose
# 20   male  2    own      moderate         little            674            12        radio/TV               1
# 42   male  2    own      little           little            3446           36        furniture/equipment    1
# 39   male  2    free     little           little            10297          48        car                    1
#            1    rent     little           little            2122           12        car                    1
#                 own      moderate         moderate          1037           12        business               1
#                                                                                                            ..
# 29   male  2    own      little           moderate          2629           20        vacation/others        1
#                                                             1103           12        radio/TV               1
# ...

# %%
gdf[gdf['Sex']=='male'].value_counts().plot(kind='pie')#male are large in number
# Out:
# <Axes: ylabel='count'>

# %%
gdf[gdf['Sex']=='female'].value_counts().plot(kind='pie')#female are less in number.
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # Job

# %%
gdf[gdf['Job']=='1']
# Out:
# Empty DataFrame
# Columns: [Age, Sex, Job, Housing, Saving accounts, Checking account, Credit amount, Duration, Purpose]
# Index: []

# %%
gdf['Job'].unique()# 0 - unskilled and non-resident, 1 - unskilled and resident, 2 - skilled, 3 - highly skilled
# Out:
# array([2, 1, 3, 0], dtype=object)

# %%
gdf['Job'].nunique()
# Out:
# 4

# %%
p=gdf[gdf['Job']==0]# this gives us the information about the jobless of male and female.In this all the values are included
p
# Out:
#      Age     Sex Job Housing Saving accounts Checking account  Credit amount  \
# 47    23  female   0    rent      quite rich           little           1352
# 140   27    male   0     own            rich             rich            709
# 187   68    male   0    free          little         moderate           1175
# 236   23    male   0     own             NaN         moderate          14555
# 300   54  female   0     own          little              NaN            672
# 310   40    male   0    free             NaN         moderate           5381
# 347   23  female   0    rent      quite rich         moderate           3758
# 364   25    male   0     own          little           little           2473
# 429   55  female   0    free          little           little           1190
# 438   65    male   0     own          little           little           3394
# 439   26  female   0     own          little             rich            609
# ...

# %%
len(p)
# Out:
# 22

# %%
# value_counts is used for only integers

# %%
p=gdf[gdf['Job']==0].value_counts()

# %%
p
# Out:
# Age  Sex     Job  Housing  Saving accounts  Checking account  Credit amount  Duration  Purpose
# 23   female  0    rent     quite rich       little            1352           6         car                    1
#                                             moderate          3758           24        radio/TV               1
# 25   male    0    own      little           little            2473           18        furniture/equipment    1
# 26   female  0    own      little           rich              609            12        business               1
#                   rent     little           moderate          1778           15        car                    1
# 27   female  0    own      little           little            750            18        education              1
#      male    0    own      rich             rich              709            6         car                    1
# ...

# %%
len(p)#nan values are removed
# Out:
# 14

# %%
x=gdf[gdf['Job']==1]#In this the unskilled and resident 
x
# Out:
#      Age     Sex Job Housing Saving accounts Checking account  Credit amount  \
# 2     49    male   1     own          little              NaN           2096
# 5     35    male   1    free             NaN              NaN           9055
# 8     61    male   1     own            rich              NaN           3059
# 13    60    male   1     own          little           little           1199
# 15    32  female   1     own        moderate           little           1282
# ..   ...     ...  ..     ...             ...              ...            ...
# 989   48    male   1     own          little         moderate           1743
# 990   37    male   1     own             NaN              NaN           3565
# 991   34    male   1     own        moderate              NaN           1569
# 992   23    male   1    rent             NaN           little           1936
# 995   31  female   1     own          little              NaN           1736
#
#      Duration              Purpose
# ...

# %%
len(x)
# Out:
# 200

# %%
x=gdf[gdf['Job']==2]
x
# Out:
#      Age     Sex Job Housing Saving accounts Checking account  Credit amount  \
# 0     67    male   2     own             NaN           little           1169
# 1     22  female   2     own          little         moderate           5951
# 3     45    male   2    free          little           little           7882
# 4     53    male   2    free          little           little           4870
# 6     53    male   2     own      quite rich              NaN           2835
# ..   ...     ...  ..     ...             ...              ...            ...
# 987   64  female   2     own        moderate              NaN           1409
# 994   50    male   2     own             NaN              NaN           2390
# 997   38    male   2     own          little              NaN            804
# 998   23    male   2    free          little           little           1845
# 999   27    male   2     own        moderate         moderate           4576
#
#      Duration              Purpose
# ...

# %%
len(x)# thw number of skilled are 630
# Out:
# 630

# %%
x=gdf[gdf['Job']==3]
x
# Out:
#      Age     Sex Job Housing Saving accounts Checking account  Credit amount  \
# 7     35    male   3    rent          little         moderate           6948
# 9     28    male   3     own          little         moderate           5234
# 18    44  female   3    free          little         moderate          12579
# 34    33  female   3     own          little             rich           1474
# 40    30    male   3     own      quite rich              NaN           2333
# ..   ...     ...  ..     ...             ...              ...            ...
# 981   33    male   3    rent          little              NaN           4844
# 982   28  female   3     own        moderate             rich           2923
# 988   29    male   3    free          little           little           6579
# 993   30    male   3     own          little           little           3959
# 996   40    male   3     own          little           little           3857
#
#      Duration              Purpose
# ...

# %%
len(x)#the number of persons who are highly skilled are 148
# Out:
# 148

# %%
gdf['Job'].value_counts().plot(kind='pie')# Pie works only on integer values
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # Housing

# %%
gdf['Housing'].unique()
# Out:
# array(['own', 'free', 'rent'], dtype=object)

# %%
gdf[gdf['Housing']=='own']#In this,the own house are 713
# Out:
#      Age     Sex Job Housing Saving accounts Checking account  Credit amount  \
# 0     67    male   2     own             NaN           little           1169
# 1     22  female   2     own          little         moderate           5951
# 2     49    male   1     own          little              NaN           2096
# 6     53    male   2     own      quite rich              NaN           2835
# 8     61    male   1     own            rich              NaN           3059
# ..   ...     ...  ..     ...             ...              ...            ...
# 994   50    male   2     own             NaN              NaN           2390
# 995   31  female   1     own          little              NaN           1736
# 996   40    male   3     own          little           little           3857
# 997   38    male   2     own          little              NaN            804
# 999   27    male   2     own        moderate         moderate           4576
#
#      Duration              Purpose
# ...

# %%
gdf[gdf['Housing']=='free']#The people who are in free house are 108
# Out:
#      Age     Sex Job Housing Saving accounts Checking account  Credit amount  \
# 3     45    male   2    free          little           little           7882
# 4     53    male   2    free          little           little           4870
# 5     35    male   1    free             NaN              NaN           9055
# 18    44  female   3    free          little         moderate          12579
# 36    31    male   2    free          little              NaN           6110
# ..   ...     ...  ..     ...             ...              ...            ...
# 938   42    male   2    free          little         moderate           6288
# 946   30    male   2    free      quite rich           little           3349
# 959   30    male   2    free        moderate         moderate           3069
# 988   29    male   3    free          little           little           6579
# 998   23    male   2    free          little           little           1845
#
#      Duration              Purpose
# ...

# %%
gdf[gdf['Housing']=='own']['Sex']
# Out:
# 0        male
# 1      female
# 2        male
# 6        male
# 8        male
#         ...
# 994      male
# 995    female
# 996      male
# 997      male
# 999      male
# Name: Sex, Length: 713, dtype: object

# %%
gdf[gdf['Housing']=='rent']#there are 173 people who are living in rented house
# Out:
#      Age     Sex Job Housing Saving accounts Checking account  Credit amount  \
# 7     35    male   3    rent          little         moderate           6948
# 10    25  female   2    rent          little         moderate           1295
# 11    24  female   2    rent          little           little           4308
# 14    28  female   2    rent          little           little           1403
# 21    44    male   2    rent      quite rich           little           2647
# ..   ...     ...  ..     ...             ...              ...            ...
# 973   36    male   2    rent          little           little           7297
# 979   25    male   2    rent        moderate         moderate           1264
# 981   33    male   3    rent          little              NaN           4844
# 985   25  female   2    rent          little           little           1433
# 992   23    male   1    rent             NaN           little           1936
#
#      Duration              Purpose
# ...

# %%
gdf['Housing'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # Saving Account

# %%
gdf['Saving accounts']
# Out:
# 0           NaN
# 1        little
# 2        little
# 3        little
# 4        little
#          ...
# 995      little
# 996      little
# 997      little
# 998      little
# 999    moderate
# Name: Saving accounts, Length: 1000, dtype: object

# %%
gdf['Saving accounts'].unique()#(text - little, moderate, quite rich, rich)
# Out:
# array([nan, 'little', 'quite rich', 'rich', 'moderate'], dtype=object)

# %%
gdf['Saving accounts'].nunique()
# Out:
# 4

# %%
gdf['Saving accounts']=='little'
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 995     True
# 996     True
# 997     True
# 998     True
# 999    False
# Name: Saving accounts, Length: 1000, dtype: bool

# %%
gdf[gdf['Saving accounts']=='little']# there are 603 people
# Out:
#      Age     Sex Job Housing Saving accounts Checking account  Credit amount  \
# 1     22  female   2     own          little         moderate           5951
# 2     49    male   1     own          little              NaN           2096
# 3     45    male   2    free          little           little           7882
# 4     53    male   2    free          little           little           4870
# 7     35    male   3    rent          little         moderate           6948
# ..   ...     ...  ..     ...             ...              ...            ...
# 993   30    male   3     own          little           little           3959
# 995   31  female   1     own          little              NaN           1736
# 996   40    male   3     own          little           little           3857
# 997   38    male   2     own          little              NaN            804
# 998   23    male   2    free          little           little           1845
#
#      Duration              Purpose
# ...

# %%
gdf[gdf['Saving accounts']=='little'].value_counts()
# Out:
# Age  Sex     Job  Housing  Saving accounts  Checking account  Credit amount  Duration  Purpose
# 20   female  1    rent     little           moderate          2718           24        car                    1
# 37   male    2    own      little           rich              1225           10        domestic appliances    1
# 39   female  2    own      little           moderate          1188           21        business               1
#                                             little            860            6         car                    1
# 38   male    3    free     little           little            10623          30        car                    1
#                                                                                                              ..
# 27   male    2    own      little           moderate          3652           21        business               1
# ...

# %%
gdf['Saving accounts'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # Checking amount

# %%
gdf['Checking account']
# Out:
# 0        little
# 1      moderate
# 2           NaN
# 3        little
# 4        little
#          ...
# 995         NaN
# 996      little
# 997         NaN
# 998      little
# 999    moderate
# Name: Checking account, Length: 1000, dtype: object

# %%
gdf['Checking account'].unique()
# Out:
# array(['little', 'moderate', nan, 'rich'], dtype=object)

# %%
gdf['Checking account'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # Credit amount

# %%
gdf['Credit amount']
# Out:
# 0      1169
# 1      5951
# 2      2096
# 3      7882
# 4      4870
#        ...
# 995    1736
# 996    3857
# 997     804
# 998    1845
# 999    4576
# Name: Credit amount, Length: 1000, dtype: int64

# %%
gdf['Credit amount'].nunique()
# Out:
# 921

# %%
gdf['Credit amount'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # Duration

# %%
gdf['Duration']
# Out:
# 0       6
# 1      48
# 2      12
# 3      42
# 4      24
#        ..
# 995    12
# 996    30
# 997    12
# 998    45
# 999    45
# Name: Duration, Length: 1000, dtype: int64

# %%
gdf['Duration'].unique()
# Out:
# array([ 6, 48, 12, 42, 24, 36, 30, 15,  9, 10,  7, 60, 18, 45, 11, 27,  8,
#        54, 20, 14, 33, 21, 16,  4, 47, 13, 22, 39, 28,  5, 26, 72, 40],
#       dtype=int64)

# %%
gdf['Duration'].nunique()
# Out:
# 33

# %%
gdf['Duration'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
gdf['Duration'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
gdf['Duration'].mean()
# Out:
# 20.903

# %% [markdown]
# # Purpose

# %%
gdf['Purpose']
# Out:
# 0                 radio/TV
# 1                 radio/TV
# 2                education
# 3      furniture/equipment
# 4                      car
#               ...
# 995    furniture/equipment
# 996                    car
# 997               radio/TV
# 998               radio/TV
# 999                    car
# Name: Purpose, Length: 1000, dtype: object

# %%
gdf['Purpose'].unique()
# Out:
# array(['radio/TV', 'education', 'furniture/equipment', 'car', 'business',
#        'domestic appliances', 'repairs', 'vacation/others'], dtype=object)

# %%
gdf['Purpose'].nunique()
# Out:
# 8

# %%
gdf['Purpose'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # The questions based on multi columns

# %% [markdown]
# # 1.Find the male who are in between the age 45 to 50

# %%
gdf['Sex']=='male'
# Out:
# 0       True
# 1      False
# 2       True
# 3       True
# 4       True
#        ...
# 995    False
# 996     True
# 997     True
# 998     True
# 999     True
# Name: Sex, Length: 1000, dtype: bool

# %%
gdf[gdf['Sex']=='male']
# Out:
#      Age   Sex Job Housing Saving accounts Checking account  Credit amount  \
# 0     67  male   2     own             NaN           little           1169
# 2     49  male   1     own          little              NaN           2096
# 3     45  male   2    free          little           little           7882
# 4     53  male   2    free          little           little           4870
# 5     35  male   1    free             NaN              NaN           9055
# ..   ...   ...  ..     ...             ...              ...            ...
# 994   50  male   2     own             NaN              NaN           2390
# 996   40  male   3     own          little           little           3857
# 997   38  male   2     own          little              NaN            804
# 998   23  male   2    free          little           little           1845
# 999   27  male   2     own        moderate         moderate           4576
#
#      Duration              Purpose
# ...

# %%
gdf['Age']>=45
# Out:
# 0       True
# 1      False
# 2       True
# 3       True
# 4       True
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: Age, Length: 1000, dtype: bool

# %%
gdf[gdf['Age']>=45]
# Out:
#      Age     Sex Job Housing Saving accounts Checking account  Credit amount  \
# 0     67    male   2     own             NaN           little           1169
# 2     49    male   1     own          little              NaN           2096
# 3     45    male   2    free          little           little           7882
# 4     53    male   2    free          little           little           4870
# 6     53    male   2     own      quite rich              NaN           2835
# ..   ...     ...  ..     ...             ...              ...            ...
# 978   47    male   1     own          little              NaN           2538
# 980   49    male   2     own          little         moderate           8386
# 987   64  female   2     own        moderate              NaN           1409
# 989   48    male   1     own          little         moderate           1743
# 994   50    male   2     own             NaN              NaN           2390
#
#      Duration              Purpose
# ...

# %%
gdf[gdf['Age']<50]
# Out:
#      Age     Sex Job Housing Saving accounts Checking account  Credit amount  \
# 1     22  female   2     own          little         moderate           5951
# 2     49    male   1     own          little              NaN           2096
# 3     45    male   2    free          little           little           7882
# 5     35    male   1    free             NaN              NaN           9055
# 7     35    male   3    rent          little         moderate           6948
# ..   ...     ...  ..     ...             ...              ...            ...
# 995   31  female   1     own          little              NaN           1736
# 996   40    male   3     own          little           little           3857
# 997   38    male   2     own          little              NaN            804
# 998   23    male   2    free          little           little           1845
# 999   27    male   2     own        moderate         moderate           4576
#
#      Duration              Purpose
# ...

# %%
x=gdf[(gdf['Age']>=45) &(gdf['Age']<50)]
x
# Out:
#      Age   Sex Job Housing Saving accounts Checking account  Credit amount  \
# 2     49  male   1     own          little              NaN           2096
# 3     45  male   2    free          little           little           7882
# 20    48  male   2     own          little              NaN           2134
# 22    48  male   1    rent          little           little           2241
# 65    48  male   2     own             NaN              NaN           5190
# ..   ...   ...  ..     ...             ...              ...            ...
# 958   45  male   1     own          little           little           4006
# 961   47  male   2     own          little         moderate           2353
# 978   47  male   1     own          little              NaN           2538
# 980   49  male   2     own          little         moderate           8386
# 989   48  male   1     own          little         moderate           1743
#
#      Duration              Purpose
# ...

# %%
len(x)# male persons who are in age between 45 and 50
# Out:
# 76

# %%
gdf[(gdf['Sex']=='male') & (gdf['Age']>=45) &(gdf['Age']<50) ]# There are 64 male persons who are in age between 45 and 50
# Out:
#      Age   Sex Job Housing Saving accounts Checking account  Credit amount  \
# 2     49  male   1     own          little              NaN           2096
# 3     45  male   2    free          little           little           7882
# 20    48  male   2     own          little              NaN           2134
# 22    48  male   1    rent          little           little           2241
# 65    48  male   2     own             NaN              NaN           5190
# ..   ...   ...  ..     ...             ...              ...            ...
# 958   45  male   1     own          little           little           4006
# 961   47  male   2     own          little         moderate           2353
# 978   47  male   1     own          little              NaN           2538
# 980   49  male   2     own          little         moderate           8386
# 989   48  male   1     own          little         moderate           1743
#
#      Duration              Purpose
# ...

# %% [markdown]
# # 2.How many of the female are jobless and housing for free

# %%
gdf[gdf['Sex']=='female']
# Out:
#      Age     Sex Job Housing Saving accounts Checking account  Credit amount  \
# 1     22  female   2     own          little         moderate           5951
# 10    25  female   2    rent          little         moderate           1295
# 11    24  female   2    rent          little           little           4308
# 12    22  female   2     own          little         moderate           1567
# 14    28  female   2    rent          little           little           1403
# ..   ...     ...  ..     ...             ...              ...            ...
# 976   64  female   2     own          little         moderate            753
# 982   28  female   3     own        moderate             rich           2923
# 985   25  female   2    rent          little           little           1433
# 987   64  female   2     own        moderate              NaN           1409
# 995   31  female   1     own          little              NaN           1736
#
#      Duration              Purpose
# ...

# %%
c=gdf[(gdf['Job']==0) & (gdf['Sex']=='female')]
c
# Out:
#      Age     Sex Job Housing Saving accounts Checking account  Credit amount  \
# 47    23  female   0    rent      quite rich           little           1352
# 300   54  female   0     own          little              NaN            672
# 347   23  female   0    rent      quite rich         moderate           3758
# 429   55  female   0    free          little           little           1190
# 439   26  female   0     own          little             rich            609
# 640   27  female   0     own          little           little            750
# 697   38  female   0     own          little              NaN            926
# 735   29  female   0     own             NaN         moderate           3990
# 804   24  female   0    rent             NaN         moderate           7472
# 809   26  female   0    rent          little         moderate           1778
# 883   65  female   0     own          little              NaN           1098
# ...

# %%
len(c)#
# Out:
# 12

# %%
p=gdf[(gdf['Job']==0) & (gdf['Sex']=='female') & (gdf['Housing']=='free')]
p
# Out:
#      Age     Sex Job Housing Saving accounts Checking account  Credit amount  \
# 429   55  female   0    free          little           little           1190
#
#      Duration  Purpose
# 429        18  repairs

# %%
len(p)# only one female person is jobless,and housing for free
# Out:
# 1

# %% [markdown]
# # 3.How many of the female are in age between 25-30,skilled or highly skilled,who wants to purchase(car)

# %%
gdf[gdf['Sex']=='female']
# Out:
#      Age     Sex Job Housing Saving accounts Checking account  Credit amount  \
# 1     22  female   2     own          little         moderate           5951
# 10    25  female   2    rent          little         moderate           1295
# 11    24  female   2    rent          little           little           4308
# 12    22  female   2     own          little         moderate           1567
# 14    28  female   2    rent          little           little           1403
# ..   ...     ...  ..     ...             ...              ...            ...
# 976   64  female   2     own          little         moderate            753
# 982   28  female   3     own        moderate             rich           2923
# 985   25  female   2    rent          little           little           1433
# 987   64  female   2     own        moderate              NaN           1409
# 995   31  female   1     own          little              NaN           1736
#
#      Duration              Purpose
# ...

# %%
gdf[gdf['Age']>25]
# Out:
#      Age     Sex Job Housing Saving accounts Checking account  Credit amount  \
# 0     67    male   2     own             NaN           little           1169
# 2     49    male   1     own          little              NaN           2096
# 3     45    male   2    free          little           little           7882
# 4     53    male   2    free          little           little           4870
# 5     35    male   1    free             NaN              NaN           9055
# ..   ...     ...  ..     ...             ...              ...            ...
# 994   50    male   2     own             NaN              NaN           2390
# 995   31  female   1     own          little              NaN           1736
# 996   40    male   3     own          little           little           3857
# 997   38    male   2     own          little              NaN            804
# 999   27    male   2     own        moderate         moderate           4576
#
#      Duration              Purpose
# ...

# %%
gdf[gdf['Age']<30]
# Out:
#      Age     Sex Job Housing Saving accounts Checking account  Credit amount  \
# 1     22  female   2     own          little         moderate           5951
# 9     28    male   3     own          little         moderate           5234
# 10    25  female   2    rent          little         moderate           1295
# 11    24  female   2    rent          little           little           4308
# 12    22  female   2     own          little         moderate           1567
# ..   ...     ...  ..     ...             ...              ...            ...
# 985   25  female   2    rent          little           little           1433
# 988   29    male   3    free          little           little           6579
# 992   23    male   1    rent             NaN           little           1936
# 998   23    male   2    free          little           little           1845
# 999   27    male   2     own        moderate         moderate           4576
#
#      Duration              Purpose
# ...

# %%
gdf[gdf['Job']==2]
# Out:
#      Age     Sex Job Housing Saving accounts Checking account  Credit amount  \
# 0     67    male   2     own             NaN           little           1169
# 1     22  female   2     own          little         moderate           5951
# 3     45    male   2    free          little           little           7882
# 4     53    male   2    free          little           little           4870
# 6     53    male   2     own      quite rich              NaN           2835
# ..   ...     ...  ..     ...             ...              ...            ...
# 987   64  female   2     own        moderate              NaN           1409
# 994   50    male   2     own             NaN              NaN           2390
# 997   38    male   2     own          little              NaN            804
# 998   23    male   2    free          little           little           1845
# 999   27    male   2     own        moderate         moderate           4576
#
#      Duration              Purpose
# ...

# %%
gdf[gdf['Job']==3]
# Out:
#      Age     Sex Job Housing Saving accounts Checking account  Credit amount  \
# 7     35    male   3    rent          little         moderate           6948
# 9     28    male   3     own          little         moderate           5234
# 18    44  female   3    free          little         moderate          12579
# 34    33  female   3     own          little             rich           1474
# 40    30    male   3     own      quite rich              NaN           2333
# ..   ...     ...  ..     ...             ...              ...            ...
# 981   33    male   3    rent          little              NaN           4844
# 982   28  female   3     own        moderate             rich           2923
# 988   29    male   3    free          little           little           6579
# 993   30    male   3     own          little           little           3959
# 996   40    male   3     own          little           little           3857
#
#      Duration              Purpose
# ...

# %%
gdf[(gdf['Job']==2) | (gdf['Job']==3)]
# Out:
#      Age     Sex Job Housing Saving accounts Checking account  Credit amount  \
# 0     67    male   2     own             NaN           little           1169
# 1     22  female   2     own          little         moderate           5951
# 3     45    male   2    free          little           little           7882
# 4     53    male   2    free          little           little           4870
# 6     53    male   2     own      quite rich              NaN           2835
# ..   ...     ...  ..     ...             ...              ...            ...
# 994   50    male   2     own             NaN              NaN           2390
# 996   40    male   3     own          little           little           3857
# 997   38    male   2     own          little              NaN            804
# 998   23    male   2    free          little           little           1845
# 999   27    male   2     own        moderate         moderate           4576
#
#      Duration              Purpose
# ...

# %%
gdf[gdf['Purpose']=='car']
# Out:
#      Age     Sex Job Housing Saving accounts Checking account  Credit amount  \
# 4     53    male   2    free          little           little           4870
# 7     35    male   3    rent          little         moderate           6948
# 9     28    male   3     own          little         moderate           5234
# 10    25  female   2    rent          little         moderate           1295
# 13    60    male   1     own          little           little           1199
# ..   ...     ...  ..     ...             ...              ...            ...
# 983   26    male   2     own          little           little           8229
# 988   29    male   3    free          little           little           6579
# 994   50    male   2     own             NaN              NaN           2390
# 996   40    male   3     own          little           little           3857
# 999   27    male   2     own        moderate         moderate           4576
#
#      Duration Purpose
# ...

# %%
gdf[(gdf['Sex']=='female') & (gdf['Age']>25) & (gdf['Age']<30) & ((gdf['Job']==2) | (gdf['Job']==3)) & gdf['Purpose']=='car']# no feamle person is either skilled or highly skilled who wants to purchase a car
# Out:
# Empty DataFrame
# Columns: [Age, Sex, Job, Housing, Saving accounts, Checking account, Credit amount, Duration, Purpose]
# Index: []

# %%
gdf[(gdf['Sex']=='male') & (gdf['Age']>25) & (gdf['Age']<30) & gdf['Purpose']=='car']
# Out:
# Empty DataFrame
# Columns: [Age, Sex, Job, Housing, Saving accounts, Checking account, Credit amount, Duration, Purpose]
# Index: []

# %% [markdown]
# # 4.How many of the jobless are having savings account and having a own house

# %%
gdf['Saving accounts'].unique()
# Out:
# array([nan, 'little', 'quite rich', 'rich', 'moderate'], dtype=object)

# %%
x=gdf[gdf['Saving accounts']=='rich']
x
# Out:
#      Age     Sex Job Housing Saving accounts Checking account  Credit amount  \
# 8     61    male   1     own            rich              NaN           3059
# 27    42  female   2    rent            rich             rich            409
# 30    36    male   2     own            rich         moderate           1913
# 67    22    male   2     own            rich         moderate           1007
# 94    54    male   2     own            rich         moderate           1318
# 136   27    male   2     own            rich              NaN           8613
# 140   27    male   0     own            rich             rich            709
# 149   46    male   2     own            rich              NaN           1582
# 153   29  female   2    rent            rich         moderate           7758
# 167   20  female   2     own            rich         moderate           1577
# 183   50    male   2     own            rich              NaN           3777
# ...

# %%
len(x)
# Out:
# 48

# %%
len(gdf[gdf['Job']==0])
# Out:
# 22

# %%
len(gdf[gdf['Housing']=='own'])
# Out:
# 713

# %%
Y=gdf[(gdf['Job']==0) & (gdf['Housing']=='own') &(gdf['Saving accounts']=='rich') ]
Y
# Out:
#      Age   Sex Job Housing Saving accounts Checking account  Credit amount  \
# 140   27  male   0     own            rich             rich            709
#
#      Duration Purpose
# 140         6     car

# %%
len(Y)# only one male person is having a savings account and jobless and own house
# Out:
# 1

# %% [markdown]
# # 5.Calculate the number  of male and female who are having a credit amount greater than 2000and duration of minimum15 months

# %%
x=gdf[gdf['Sex']=='male']
x
# Out:
#      Age   Sex Job Housing Saving accounts Checking account  Credit amount  \
# 0     67  male   2     own             NaN           little           1169
# 2     49  male   1     own          little              NaN           2096
# 3     45  male   2    free          little           little           7882
# 4     53  male   2    free          little           little           4870
# 5     35  male   1    free             NaN              NaN           9055
# ..   ...   ...  ..     ...             ...              ...            ...
# 994   50  male   2     own             NaN              NaN           2390
# 996   40  male   3     own          little           little           3857
# 997   38  male   2     own          little              NaN            804
# 998   23  male   2    free          little           little           1845
# 999   27  male   2     own        moderate         moderate           4576
#
#      Duration              Purpose
# ...

# %%
y=gdf[gdf['Sex']=='female']
y
# Out:
#      Age     Sex Job Housing Saving accounts Checking account  Credit amount  \
# 1     22  female   2     own          little         moderate           5951
# 10    25  female   2    rent          little         moderate           1295
# 11    24  female   2    rent          little           little           4308
# 12    22  female   2     own          little         moderate           1567
# 14    28  female   2    rent          little           little           1403
# ..   ...     ...  ..     ...             ...              ...            ...
# 976   64  female   2     own          little         moderate            753
# 982   28  female   3     own        moderate             rich           2923
# 985   25  female   2    rent          little           little           1433
# 987   64  female   2     own        moderate              NaN           1409
# 995   31  female   1     own          little              NaN           1736
#
#      Duration              Purpose
# ...

# %%
gdf[gdf['Credit amount']>2000]#568 are having credit amount greater than 2000
# Out:
#      Age     Sex Job Housing Saving accounts Checking account  Credit amount  \
# 1     22  female   2     own          little         moderate           5951
# 2     49    male   1     own          little              NaN           2096
# 3     45    male   2    free          little           little           7882
# 4     53    male   2    free          little           little           4870
# 5     35    male   1    free             NaN              NaN           9055
# ..   ...     ...  ..     ...             ...              ...            ...
# 990   37    male   1     own             NaN              NaN           3565
# 993   30    male   3     own          little           little           3959
# 994   50    male   2     own             NaN              NaN           2390
# 996   40    male   3     own          little           little           3857
# 999   27    male   2     own        moderate         moderate           4576
#
#      Duration              Purpose
# ...

# %%
gdf[gdf['Duration']>15]
# Out:
#      Age     Sex Job Housing Saving accounts Checking account  Credit amount  \
# 1     22  female   2     own          little         moderate           5951
# 3     45    male   2    free          little           little           7882
# 4     53    male   2    free          little           little           4870
# 5     35    male   1    free             NaN              NaN           9055
# 6     53    male   2     own      quite rich              NaN           2835
# ..   ...     ...  ..     ...             ...              ...            ...
# 992   23    male   1    rent             NaN           little           1936
# 993   30    male   3     own          little           little           3959
# 996   40    male   3     own          little           little           3857
# 998   23    male   2    free          little           little           1845
# 999   27    male   2     own        moderate         moderate           4576
#
#      Duration              Purpose
# ...

# %%
a=gdf[(gdf['Sex']=='female') & (gdf['Credit amount']>2000) & (gdf['Duration']>15) ]#109 female person are having a credit amount greater than 2000 and duration above 15 months
a
# Out:
#      Age     Sex Job Housing Saving accounts Checking account  Credit amount  \
# 1     22  female   2     own          little         moderate           5951
# 11    24  female   2    rent          little           little           4308
# 18    44  female   3    free          little         moderate          12579
# 44    58  female   1    free          little           little           6143
# 57    31  female   2     own          little              NaN           9566
# ..   ...     ...  ..     ...             ...              ...            ...
# 945   30  female   2     own      quite rich         moderate           8358
# 952   28  female   2    rent      quite rich         moderate           4113
# 953   26  female   3     own          little              NaN          10974
# 974   33  female   2     own          little              NaN           2831
# 982   28  female   3     own        moderate             rich           2923
#
#      Duration              Purpose
# ...

# %%
b=gdf[(gdf['Sex']=='male') & (gdf['Credit amount']>2000) & (gdf['Duration']>15) ]#324 male persons.
b
# Out:
#      Age   Sex Job Housing Saving accounts Checking account  Credit amount  \
# 3     45  male   2    free          little           little           7882
# 4     53  male   2    free          little           little           4870
# 5     35  male   1    free             NaN              NaN           9055
# 6     53  male   2     own      quite rich              NaN           2835
# 7     35  male   3    rent          little         moderate           6948
# ..   ...   ...  ..     ...             ...              ...            ...
# 986   33  male   2     own          little             rich           6289
# 988   29  male   3    free          little           little           6579
# 993   30  male   3     own          little           little           3959
# 996   40  male   3     own          little           little           3857
# 999   27  male   2     own        moderate         moderate           4576
#
#      Duration              Purpose
# ...
