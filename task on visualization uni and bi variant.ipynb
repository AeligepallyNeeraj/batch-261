# %%
import pandas as pd,seaborn as sns

# %%
tdf=pd.read_csv(r"C:\Users\yuvin\Downloads\titanic.csv")
tdf
# Out:
#      Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
# ..          ...       ...     ...     ...   ...    ...    ...      ...
# 886         886         0       2    male  27.0      0      0  13.0000
# 887         887         1       1  female  19.0      0      0  30.0000
# 888         888         0       3  female   NaN      1      2  23.4500
# 889         889         1       1    male  26.0      0      0  30.0000
# 890         890         0       3    male  32.0      0      0   7.7500
#
#     embarked   class    who  adult_male deck  embark_town alive  alone
# ...

# %%
tdf.isnull().sum()
# Out:
# Unnamed: 0       0
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
tdf.drop(columns='deck')
# Out:
#      Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
# ..          ...       ...     ...     ...   ...    ...    ...      ...
# 886         886         0       2    male  27.0      0      0  13.0000
# 887         887         1       1  female  19.0      0      0  30.0000
# 888         888         0       3  female   NaN      1      2  23.4500
# 889         889         1       1    male  26.0      0      0  30.0000
# 890         890         0       3    male  32.0      0      0   7.7500
#
#     embarked   class    who  adult_male  embark_town alive  alone
# ...

# %%
tdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   891 non-null    int64
#  1   survived     891 non-null    int64
#  2   pclass       891 non-null    int64
#  3   sex          891 non-null    object
#  4   age          714 non-null    float64
#  5   sibsp        891 non-null    int64
#  6   parch        891 non-null    int64
#  7   fare         891 non-null    float64
#  8   embarked     889 non-null    object
#  9   class        891 non-null    object
#  10  who          891 non-null    object
#  11  adult_male   891 non-null    bool
#  12  deck         203 non-null    object
#  13  embark_town  889 non-null    object
#  14  alive        891 non-null    object
#  15  alone        891 non-null    bool
# dtypes: bool(2), float64(2), int64(5), object(7)
# memory usage: 99.3+ KB

# %%
tdf.isnull().sum().sum()
# Out:
# 869

# %%
tdf=tdf.ffill()
tdf
# Out:
#      Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
# ..          ...       ...     ...     ...   ...    ...    ...      ...
# 886         886         0       2    male  27.0      0      0  13.0000
# 887         887         1       1  female  19.0      0      0  30.0000
# 888         888         0       3  female  19.0      1      2  23.4500
# 889         889         1       1    male  26.0      0      0  30.0000
# 890         890         0       3    male  32.0      0      0   7.7500
#
#     embarked   class    who  adult_male deck  embark_town alive  alone
# ...

# %%
tdf
# Out:
#      Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
# ..          ...       ...     ...     ...   ...    ...    ...      ...
# 886         886         0       2    male  27.0      0      0  13.0000
# 887         887         1       1  female  19.0      0      0  30.0000
# 888         888         0       3  female  19.0      1      2  23.4500
# 889         889         1       1    male  26.0      0      0  30.0000
# 890         890         0       3    male  32.0      0      0   7.7500
#
#     embarked   class    who  adult_male deck  embark_town alive  alone
# ...

# %%
tdf.isnull().sum().sum()
# Out:
# 1

# %%
tdf
# Out:
#      Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
# ..          ...       ...     ...     ...   ...    ...    ...      ...
# 886         886         0       2    male  27.0      0      0  13.0000
# 887         887         1       1  female  19.0      0      0  30.0000
# 888         888         0       3  female  19.0      1      2  23.4500
# 889         889         1       1    male  26.0      0      0  30.0000
# 890         890         0       3    male  32.0      0      0   7.7500
#
#     embarked   class    who  adult_male deck  embark_town alive  alone
# ...

# %%
tdf['fare'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
sns.histplot(data=tdf,x='fare',bins=20)
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %%
Q1 = tdf['fare'].quantile(0.25)
Q3 = tdf['fare'].quantile(0.75)
IQR = Q3 - Q1

# %%
IQR
# Out:
# 23.0896

# %%
# Define upper and lower bounds for identifying outliers
lower_whisker = Q1 - 1.5 * IQR
upper_whisker = Q3 + 1.5 * IQR

# Identify outliers based on IQR
outliers_iqr = tdf[abs(tdf['fare'] < lower_whisker) | (tdf['fare'] > upper_whisker)]

# Display outliers
print("\nOutliers identified using IQR:")
print(outliers_iqr[['fare']])
# Out:
# Outliers identified using IQR:
#          fare
# 1     71.2833
# 27   263.0000
# 31   146.5208
# 34    82.1708
# 52    76.7292
# ..        ...
# 846   69.5500
# 849   89.1042
# 856  164.8667
# 863   69.5500
# 879   83.1583
#
# [116 rows x 1 columns]

# %%
tdf['fare'].clip()
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: fare, Length: 891, dtype: float64

# %%
sns.histplot(data=tdf,x=tdf['fare'],bins=20)
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %%
lower_whisker = 0
upper_whisker = 65.6344

# Clip 'fare' values to the defined thresholds
tdf['fare_clipped'] = tdf['fare'].clip(lower=lower_whisker, upper=upper_whisker)

# %%
tdf['fare_clipped']
# Out:
# 0       7.2500
# 1      65.6344
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: fare_clipped, Length: 891, dtype: float64

# %%
sns.histplot(data=tdf,x=tdf['fare_clipped'],bins=20)
# Out:
# <Axes: xlabel='fare_clipped', ylabel='Count'>

# %%
tdf
# Out:
#      Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
# ..          ...       ...     ...     ...   ...    ...    ...      ...
# 886         886         0       2    male  27.0      0      0  13.0000
# 887         887         1       1  female  19.0      0      0  30.0000
# 888         888         0       3  female  19.0      1      2  23.4500
# 889         889         1       1    male  26.0      0      0  30.0000
# 890         890         0       3    male  32.0      0      0   7.7500
#
#     embarked   class    who  adult_male deck  embark_town alive  alone  \
# ...

# %%
tdf.describe()
# Out:
#        Unnamed: 0    survived      pclass        age       sibsp       parch  \
# count  891.000000  891.000000  891.000000  891.00000  891.000000  891.000000
# mean   445.000000    0.383838    2.308642   29.58156    0.523008    0.381594
# std    257.353842    0.486592    0.836071   14.55459    1.102743    0.806057
# min      0.000000    0.000000    1.000000    0.42000    0.000000    0.000000
# 25%    222.500000    0.000000    2.000000   20.00000    0.000000    0.000000
# 50%    445.000000    0.000000    3.000000   28.00000    0.000000    0.000000
# 75%    667.500000    1.000000    3.000000   38.00000    1.000000    0.000000
# max    890.000000    1.000000    3.000000   80.00000    8.000000    6.000000
#
#              fare  fare_clipped
# count  891.000000    891.000000
# mean    32.204208     24.046813
# std     49.693429     20.481625
# min      0.000000      0.000000
# 25%      7.910400      7.910400
# 50%     14.454200     14.454200
# 75%     31.000000     31.000000
# ...

# %% [markdown]
# # Uni vaiant analysis

# %%
sns.histplot(tdf,x='age')
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.histplot(tdf,x='sex',color='red')# uni variantanalysis
# Out:
# <Axes: xlabel='sex', ylabel='Count'>

# %%
sns.countplot(tdf,x='sex',color='red')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.histplot(tdf,x='pclass',color='green')#uni variant
# Out:
# <Axes: xlabel='pclass', ylabel='Count'>

# %%
sns.countplot(tdf,x='pclass',color='green')
# Out:
# <Axes: xlabel='pclass', ylabel='count'>

# %%
sns.countplot(tdf,x='embarked',color='yellow')
# Out:
# <Axes: xlabel='embarked', ylabel='count'>

# %%
sns.histplot(tdf,x='pclass',color='yellow')
# Out:
# <Axes: xlabel='pclass', ylabel='Count'>

# %%
sns.countplot(tdf,x='survived',color='violet')
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
sns.histplot(tdf,x='survived',color='violet')
# Out:
# <Axes: xlabel='survived', ylabel='Count'>

# %%
tdf['pclass'].plot(kind='pie')
# Out:
# <Axes: ylabel='pclass'>

# %% [markdown]
# # Bi-variant analysis

# %%
sns.histplot(data=tdf,x='age',bins=20,hue='pclass')# this is used for finding age of people in which class there were present
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.histplot(data=tdf,x='age',bins=20,hue='pclass',multiple='dodge')
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.histplot(data=tdf,x='age',bins=20,hue='pclass',multiple='stack')
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.histplot(data=tdf,x='age',bins=20,hue='survived')
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.histplot(data=tdf,x='age',bins=20,hue='survived',multiple='dodge')
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.histplot(data=tdf,x='age',bins=20,hue='sex')
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.histplot(data=tdf,x='sex',bins=20,hue='survived',multiple='dodge')
# Out:
# <Axes: xlabel='sex', ylabel='Count'>

# %%
sns.histplot(data=tdf,x='survived',bins=20,hue='survived',multiple='dodge')
# Out:
# <Axes: xlabel='survived', ylabel='Count'>

# %%
sns.histplot(data=tdf,x='survived',bins=20,hue='pclass',multiple='dodge')
# Out:
# <Axes: xlabel='survived', ylabel='Count'>

# %%
sns.histplot(data=tdf,x='survived',bins=20,hue='pclass',multiple='stack')
# Out:
# <Axes: xlabel='survived', ylabel='Count'>

# %%
sns.histplot(data=tdf,x='survived',bins=20,hue='embarked',multiple='dodge')
# Out:
# <Axes: xlabel='survived', ylabel='Count'>

# %%
sns.countplot(data=tdf,x='survived',hue='embarked')
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
sns.histplot(data=tdf,x='survived',bins=20,hue='sex',multiple='dodge')
# Out:
# <Axes: xlabel='survived', ylabel='Count'>

# %%
sns.countplot(data=tdf,x='survived',hue='pclass')
# Out:
# <Axes: xlabel='survived', ylabel='count'>
